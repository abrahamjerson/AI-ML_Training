# %% [markdown]
# ## Fuzzy C Means Clustering

# %%
"""
Fuzzy C-Mean in Python
To give an example in Python we will create our own data using numpy
(skfuzzy documentation)
"""

# !pip install -U scikit-fuzzy
# Out:
# Requirement already up-to-date: scikit-fuzzy in c:\programdata\anaconda3\lib\site-packages (0.4.2)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz

# %%
colors = ['b', 'orange', 'g', 'r', 'c']

#Define 3 cluster centers
centers = [[1,2], [1,5], [4,4]]

#Define three cluster sigmas in x and y respectively
sigmas = [[0.8, 0.3], [0.3, 0.5], [1.1, 0.7]]

# %%
#Generate test data

np.random.seed(2) #Get seed for reproducibility
xpts = np.zeros(1)
ypts = np.zeros(1)
labels = np.zeros(1)

#np.hstack() function is used to stack the sequence of input arrays horizontally column-wise to make a single array

for i, ((xmu, ymu), (xsigma, ysigma)) in enumerate (zip(centers, sigmas)):
    xpts = np.hstack((xpts, np.random.standard_normal(200) * xsigma + xmu))
    ypts = np.hstack((ypts, np.random.standard_normal(200) * ysigma + ymu))
    labels = np.hstack((labels, np.ones(200) * i))
labels.shape
# Out:
# (601,)

# %%
"""
Here we create our data and plotted them in figure. 
With a human eye. There are 3 distinct clusters
"""

#Visualize the test data

fig0, ax0 = plt.subplots()

for label in range(3):
    ax0.plot(xpts[labels == label], ypts[labels == label], '.', color = 'b')
    
ax0.set_title('Test data: 200 points x 3 clusters')
# Out:
# Text(0.5, 1.0, 'Test data: 200 points x 3 clusters')

# %%
"""
We will see which number of cluster best produces the clustering model.
To be able to achieve that we will loop from 32 to 5 numbers of clusters (named centers in this library):
"""

#Clustering

#set up the loop and plot

fig1, axes1 = plt.subplots(2, 2, figsize = (8,8))
alldata = np.vstack((xpts, ypts))
fpcs = []

for ncenters, ax in enumerate(axes1.reshape(-1), 2):
    cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(alldata, ncenters, 2, error= 0.005, maxiter = 1000, init=None)
    
    #Store fpc values for later
    fpcs.append(fpc)
    
    #Plot assigned clusters, for each data point in training set
    clusteruster_membership = np.argmax(u, axis=0)
    for j in range(ncenters): 
        ax.plot(xpts[clusteruster_membership == j], 
                ypts[clusteruster_membership == j], '.', color=colors[j])
    
    #Mark the center of each fuzzy cluster
    for pt in cntr:
        ax.plot(pt[0], pt[1], 'rs')
        
    ax.set_title('Centers = {0}; FPC = {1:.2f}'.format(ncenters, fpc), size=12)
    ax.axis('off')

    fig1.tight_layout

# %% [markdown]
# ## Gaussian Mixture Modelling

# %%
#GMM2D

# %matplotlib inline
import seaborn as sns; sns.set()
from sklearn.mixture import GaussianMixture
import warnings
warnings.filterwarnings('ignore')

#Generate some data
from sklearn.datasets.samples_generator import make_blobs

X,y_true = make_blobs(n_samples = 400, centers=2, cluster_std = 0.60, random_state=0)

X = X[:, ::-1] #Flip axes for better plotting

# %%
#plt.plot(X[:,0], X[:,1], 'bx')

plt.scatter(X[:,0], X[:,1], s=10, cmap='viridis')
plt.axis('equal')
plt.show()

# %%
"""
n_components: int, defaults to 1.
              The number of mixture components
              
covariance_type: {‘full’ (default), ‘tied’, ‘diag’, ‘spherical’}
                 String describing the type of covariance parameters to use. Must be one of:
                ‘full’
                    each component has its own general covariance matrix
                ‘tied’
                    all components share the same general covariance matrix
                ‘diag’
                    each component has its own diagonal covariance matrix
                ‘spherical’
                    each component has its own single variance

tol: float, defaults to 1e-3.
     The convergence threshold. EM iterations will stop when the lower bound average gain is below this threshold

reg_covar: float, defaults to 1e-6.
           Non-negative regularization added to the diagonal of covariance. Allows to assure that the covariance matrices are all positive

max_iter: int, defaults to 100.
          The number of EM iterations to perform

n_init: int, defaults to 1.
        The number of initializations to perform. The best results are kept

init_params: {‘kmeans’, ‘random’}, defaults to ‘kmeans’.
             The method used to initialize the weights, the means and the precisions
                'kmeans' : responsibilities are initialized using kmeans.
                'random' : responsibilities are initialized randomly

weights_init: array-like, shape (n_components, ), optional
              The user-provided initial weights, defaults to None. If it None, weights are initialized using the init_params method

means_init: array-like, shape (n_components, n_features), optional
            The user-provided initial means, defaults to None, If it None, means are initialized using the init_params method

precisions_init: array-like, optional.
                 The user-provided initial precisions (inverse of the covariance matrices), defaults to None. If it None, precisions are initialized using the ‘init_params’ method. The shape depends on ‘covariance_type’:
                    (n_components,)                        if 'spherical',
                    (n_features, n_features)               if 'tied',
                    (n_components, n_features)             if 'diag',
                    (n_components, n_features, n_features) if 'full'

random_state: int, RandomState instance or None, optional (default=None)
              Controls the random seed given to the method chosen to initialize the parameters (see init_params). In addition, it controls the generation of random samples from the fitted distribution (see the method sample). Pass an int for reproducible output across multiple function calls

warm_start: bool, default to False.
            If ‘warm_start’ is True, the solution of the last fitting is used as initialization for the next call of fit(). This can speed up convergence when fit is called several times on similar problems. In that case, ‘n_init’ is ignored and only a single initialization occurs upon the first call

verbose: int, default to 0.
         Enable verbose output. If 1 then it prints the current initialization and each iteration step. If greater than 1 then it prints also the log probability and the time needed for each step

verbose_interval: int, default to 10.
                  Number of iteration done before the next print
"""

gmm = GaussianMixture(n_components = 2)

#gmm.fit(X_train)
labels = gmm.fit(X).predict(X)

# %%
plt.scatter(X[:,0], X[:,1], c = labels, s=10, cmap='viridis')
plt.axis('equal')
plt.show()

# %%
#Mean value of this algorithm
print(gmm.means_.round(2))
# Out:
# [[0.83 1.99]
#  [4.3  0.93]]

# %%
#Co-vaiance of this algoritm
#The matrix - covariances diagonal  elements are close to root of cluster std = 0.6

print(gmm.covariances_.round(2))
# Out:
# [[[ 0.38  0.01]
#   [ 0.01  0.35]]
#
#  [[ 0.34 -0.02]
#   [-0.02  0.35]]]

# %%
X1, Y1 = np.meshgrid(np.linspace(-5,10), np.linspace(-5, 10))
XX = np.array([X1.ravel(), Y1.ravel()]).T
Z1 = gmm.score_samples(XX)
Z1 = Z1.reshape((50,50))

plt.contour(X1, Y1, Z1)
#plt.scatter (X_train[:, 0], X_train[:, 1])
plt.scatter(X[:,0], X[:,1])
plt.show()

# %% [markdown]
# ## Dimensionality reduction with PCA

# %% [markdown]
# ### Visualization wiht K-Means

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
import matplotlib.colors

# %%
digits = load_digits()
data = scale(digits.data)
digits.data.shape
# Out:
# (1797, 64)

# %%
np.random.seed(42)
n_samples, n_features = data.shape
n_digits = len(np.unique(digits.target))
labels = digits.target

# %%
# Visualize the results on PCA - reduced data
#The algorithm knows nothing about the data. We just apply the Algorithm to a totally nuknown data

reduced_data = PCA(n_components=2).fit_transform(data)
kmeans = KMeans(init='k-means++', n_clusters = n_digits, n_init=10)
kmeans.fit(reduced_data)
reduced_data.shape
# Out:
# (1797, 2)

# %%
#Step size of the mesh. Decrease to increase the quality of the VQ.

h=0.02 #Point in the mesh [x_min, x_max] x [y_min, y_max]

#Plot the decision boundary. For that, we will assign a clor to each

x_min, x_max = reduced_data[:, 0].min() -1, reduced_data[:, 0].max() +1
y_min, y_max = reduced_data[:, 1].min() -1, reduced_data[:, 1].max() +1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# %%
#Obtain labels for each point in mesh. Use last trained model

Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()]) #np.c_ To combine two 1D arrays

# %%
#Put the result into a color plot

Z = Z.reshape(xx.shape)
plt.figure(1)
plt.clf()
plt.imshow(Z, interpolation='nearest', extent=(xx.min(), xx.max(), yy.min(), yy.max()),
          cmap = plt.cm.Paired, 
           aspect = 'auto', origin='lower')

plt.plot(reduced_data[:, 0], reduced_data[:, 1], 'k', markersize=2)

#Plot the centroids as white X
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], marker = 'x', s=169, linewidth=3, color='w', zorder=10)

plt.title('Kmeans clustering on the digits dataset (PCA-reduced data)\n'
         'Centroids are marked with white cross')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
yy.ravel().size
# Out:
# 879723

# %%
#To check our KMeans for a certain element
kmeans.predict(np.c_[xx.ravel()[80000], yy.ravel()[80000]])
# Out:
# array([6])

# %% [markdown]
# ## Market Basket Analysis

# %%
#MBA



dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns = te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
#Return the items and itemsets with at least 60% support

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

apriori(df, min_support=0.6)
# Out:
#     support   itemsets
# 0       0.8        (3)
# 1       1.0        (5)
# 2       0.6        (6)
# 3       0.6        (8)
# 4       0.6       (10)
# 5       0.8     (3, 5)
# 6       0.6     (8, 3)
# 7       0.6     (5, 6)
# 8       0.6     (8, 5)
# 9       0.6    (10, 5)
# 10      0.6  (8, 3, 5)

# %%
apriori(df, min_support = 0.6, use_colnames=True)
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Kidney Beans, Eggs)
# 6       0.6                (Onion, Eggs)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Kidney Beans, Onion, Eggs)

# %%
frequent_itemsets2 = apriori(df, min_support = 0.5, use_colnames=True)
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)

# %%
rules2[(rules2['lift'] >= 1.25) & (rules2['confidence'] >=0.6)]
# Out:
#               antecedents           consequents  antecedent support  \
# 2                 (Onion)                (Eggs)                 0.6
# 10  (Kidney Beans, Onion)                (Eggs)                 0.6
# 14                (Onion)  (Kidney Beans, Eggs)                 0.6
#
#     consequent support  support  confidence  lift  leverage  conviction
# 2                  0.8      0.6         1.0  1.25      0.12         inf
# 10                 0.8      0.6         1.0  1.25      0.12         inf
# 14                 0.8      0.6         1.0  1.25      0.12         inf

# %%
rules2 [(rules2['confidence'] >= 1)]
# Out:
#               antecedents           consequents  antecedent support  \
# 1                  (Eggs)        (Kidney Beans)                 0.8
# 2                 (Onion)                (Eggs)                 0.6
# 4                  (Milk)        (Kidney Beans)                 0.6
# 7                 (Onion)        (Kidney Beans)                 0.6
# 9                (Yogurt)        (Kidney Beans)                 0.6
# 10  (Kidney Beans, Onion)                (Eggs)                 0.6
# 12          (Onion, Eggs)        (Kidney Beans)                 0.6
# 14                (Onion)  (Kidney Beans, Eggs)                 0.6
#
#     consequent support  support  confidence  lift  leverage  conviction
# 1                  1.0      0.8         1.0  1.00      0.00         inf
# 2                  0.8      0.6         1.0  1.25      0.12         inf
# 4                  1.0      0.6         1.0  1.00      0.00         inf
# ...

# %%
rules2 [(rules2['lift'] >= 1.25)]
# Out:
#               antecedents           consequents  antecedent support  \
# 2                 (Onion)                (Eggs)                 0.6
# 10  (Kidney Beans, Onion)                (Eggs)                 0.6
# 14                (Onion)  (Kidney Beans, Eggs)                 0.6
#
#     consequent support  support  confidence  lift  leverage  conviction
# 2                  0.8      0.6         1.0  1.25      0.12         inf
# 10                 0.8      0.6         1.0  1.25      0.12         inf
# 14                 0.8      0.6         1.0  1.25      0.12         inf

# %% [markdown]
# ### Collaborative filtering and Recommender Systems

# %%
#Collaborative Filtering

#Need uploading file.tsv, Movie_Id_Titles data

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#Get the data

column_names = ['user_id', 'item_id', 'rating', 'timestamp']

dff = pd.read_csv('C:/Users/ASUS/Desktop/Desktop Miscellaneous/ML Training Data/file.tsv',sep = '\t', names=column_names)

# %%
#Check head of data
df = dff[0:200]
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
#check out all the movies and their respective IDs

movie_titles = pd.read_csv('C:/Users/ASUS/Desktop/Desktop Miscellaneous/ML Training Data/Movie_Id_Titles.csv')
movie_titles.head()
movie_titles1 = movie_titles[0:200]
movie_titles1.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
moviedata1 = pd.merge(df, movie_titles1, on='item_id')
moviedata1.head()
# Out:
#    user_id  item_id  rating  timestamp                            title
# 0        0       50       5  881250949                 Star Wars (1977)
# 1        0      172       5  881250949  Empire Strikes Back, The (1980)
# 2      213      172       5  878955442  Empire Strikes Back, The (1980)
# 3        0      133       1  881250949        Gone with the Wind (1939)
# 4      244       51       2  880606923       Legends of the Fall (1994)

# %%
#Creating dataframe with 'rating' count values

mean_ratings1 = pd.DataFrame(moviedata1.groupby('title')['rating'].mean())

mean_ratings1['num of ratings'] = pd.DataFrame(moviedata1.groupby('title')['rating'].count())

mean_ratings1.head()
# Out:
#                               rating  num of ratings
# title
# 2001: A Space Odyssey (1968)     3.5               2
# Abyss, The (1989)                4.0               1
# Aladdin (1992)                   5.0               1
# Angels and Insects (1995)        3.0               1
# Batman Forever (1995)            3.0               1

# %%
#Sorting values according to the 'num of rating' column

#Pivot 

moviemat1 = moviedata1.pivot_table(index = 'user_id', columns ='title', values = 'rating')

# %%
mean_ratings1.sort_values('num of ratings', ascending = False).head(10)
# Out:
#                                        rating  num of ratings
# title
# Die Hard (1988)                      4.250000               4
# Rock, The (1996)                     3.333333               3
# Silence of the Lambs, The (1991)     4.333333               3
# 2001: A Space Odyssey (1968)         3.500000               2
# Terminator, The (1984)               5.000000               2
# Get Shorty (1995)                    4.500000               2
# Taxi Driver (1976)                   4.500000               2
# Empire Strikes Back, The (1980)      5.000000               2
# Truth About Cats & Dogs, The (1996)  3.500000               2
# Twister (1996)                       3.000000               2

# %%
#analysing correlation with similar movies

starwars_user_ratings = moviemat1['Star Wars (1977)']

# %%
similar_to_starwars  = moviemat1.corrwith(starwars_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars, columns = ['Correlation'])
corr_starwars.dropna(inplace = True)
corr_starwars.head()
# Out:
# Empty DataFrame
# Columns: [Correlation]
# Index: []
