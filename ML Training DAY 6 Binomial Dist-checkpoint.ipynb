# %%
#Visualizing Seaborn is a Python visualization library based on matplotlib.
#It provides a high-level interface for drawing attractive statistical graphics.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''You can use Seaborn's distplot to plot the histogram of the distribution you just created. Seaborn's distplot takes in multiple arguments to customize the plot. 
You first create a plot Object ax. Here, you can specify the number of bins in the histogram, specify the color of the histogram and specify density plot option with kde and linewidth option with hist_kws. You can also set labels for x and y axis using the xlabel and ylabel arguments. 
Kernel Density Estimation (KDE) is a way to estimate the probability density function Of a continuous random variable. 
It is used for non-parametric analysis. 
Setting the hist flag to False in distplot Will yield the kernel density estimation plot. 
Visualizing the distribution you just created using seaborn's distplot renders the following histogram: 
The Bemoulli distribution has only two outcomes either I or O. The number of trials n l. If the observation of trial equals1 then it is considered success otherwise the outcome is a failure.'''
from scipy.stats import binom
data_binom = binom.rvs(n=20, p=0.8, size=10000)

# %%
ax = sns.distplot(data_binom, kde=True,color='grey',hist_kws={"histtype":"bar","linewidth": 3, 'alpha':1})
ax.set(xlabel = 'Binomial Distribution', ylabel = 'Frequency')
plt.plot()
# Out:
# []
